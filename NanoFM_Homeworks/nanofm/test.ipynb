# %%
import torch
import torch.nn as nn

# %%
if False == 0:
    print("Yes")
# Out:
# Yes

# %%
from nanofm.modeling.transformer_layers import Mlp
# Out:
# Traceback (most recent call last):
#
#   File ~/miniconda3/envs/nanofm/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3579 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[7], line 1
#     from nanofm.modeling.transformer_layers import Mlp
#
#   File /mnt/c/dev/exchange/cs_503_visual_language/NanoFM_Homeworks/nanofm/modeling/transformer_layers.py:92
#     ???
#     ^
# SyntaxError: invalid syntax

# %%
x = torch.randn(10)


model = Mlp(10, 40)
out = model(x)
out
